# %% [markdown]
# # DWDM-Lab-CSE-5021_Lab-Assignment-5:- Demonstration of Web Mining through Implementation of Web Scrapping mainly using two python libraries :  'requests' and 'BeautifulSoup' on the  Weather forecast data for downtown San Francisco from the National Weather Service’s website of the US

# %% [markdown]
# Submitted By: 20MAI0001 - NIHARIKA MAITRA
#
# To find the Input data and the .ipynb file used for this Assignment please visit :
#
# Link for Input data / Web Page Link on which Web Scrapping is implented :
#
# https://forecast.weather.gov/MapClick.php?lat=37.7772&lon=-122.4168
#
# https://forecast.weather.gov/MapClick.php?lat=37.7772&lon=-122.4168#.YJzwkUzhVPY
#
#
# Git Repo link:
#
#
# https://github.com/Niharika-20-MAI-01/Winter-2021-DWDM-LabCSE5021-Niharika-20MAI01/blob/main/20MAI0001_DWDM-Lab-CSE-5021_Lab-Assignment-5%20%20Demonstration%20of%20Web%20Mining%20through%20Implementation%20of%20Web%20Scrapping.ipynb
#
#
# https://github.com/Niharika-20-MAI-01/Winter-2021-DWDM-LabCSE5021-Niharika-20MAI01/blob/main/20MAI0001_DWDM-Lab-CSE-5021_Lab-Assignment-5%20%20Demonstration%20of%20Web%20Mining%20through%20Implementation%20of%20Web%20Scrapping.ipynb
#
# https://github.com/Niharika-20-MAI-01/Winter-2021-DWDM-LabCSE5021-Niharika-20MAI01

# %% [markdown]
# # A Brief note on Web Scrapping:

# %% [markdown]
# In order to perform Web Scrapping : we write code that sends a request to the server that’s hosting the page we specified.
# The server will return the source code — HTML, mostly — for the page (or pages) we requested.
# Unlike a web browser, in web scraping code won't interpret the page's source code and display the page visually, instead,  some custom code has to be implemented that filters through the page's source code looking for specific elements we’ve specified, and extracting whatever content we’ve instructed it to extract.
#
# As an example, In order to get  all of the data from inside a table that was displayed on a web page, our code would be written to go through these steps in sequence:
#     1)Request the content (source code) of a specific URL from the server
#
#     2)Download the content that is returned
#
#     3)Identify the elements of the page that are part of the table we want
#
#     4)Extract and (if necessary) reformat those elements into a dataset we can analyze or use in whatever way we require.

# %% [markdown]
# # A short description on the Components of a Web Page :

# %% [markdown]
# While visiting a web page, our web browser makes a request to a web server.
#
# This request is called a GET request, since we request to get files from the server.
#
# The server then sends back files that tell our browser how to render the page for us.
#
# These files typically include:
#
#     HTML — the main content of the page.
#
#     CSS — used to add styling to make the page look nicer.
#
#     JS — Javascript files add interactivity to web pages.
#
#     Images — image formats, such as JPG and PNG, allow web pages to show pictures.
#
#    After our browser receives all the files, it renders the page and displays it to us.

# %% [markdown]
# # A brief note on HTML :

# %% [markdown]
# While performing Web Scraping, we’re interested in the main content of the web page, so we look primarily at the HTML.
#
# HyperText Markup Language (HTML) is the language that web pages are created in. HTML is a markup language that tells a browser how to display content.
#
# HTML consists of elements called tags, most commonly used HTML tags are :
#
#     The most basic tag is the <html> tag. This tag tells the web browser that everything inside of it is HTML.The head tag contains data about the title of the page.
#
#     Body Tag - The main content of the web page goes into the body tag.
#
#     p tag - defines a paragraph, and any text inside the tag is shown as a separate paragraph.
#
#     div tag — indicates a division, or area, of the page.
#
#     b tag — bolds any text inside.
#
#     i tag — italicizes any text inside.
#
#     table tag — creates a table.
#
#     form tag — creates an input form.
#
# Some of the tags have commonly used names that depend on their position in relation to other tags:
#
#     child — a child is a tag inside another tag. So the two p tags above       are both children of the body tag.
#
#     parent — a parent is the tag another tag is inside. Above, the html       tag is the parent of the body tag.
#
#     sibiling — a sibiling is a tag that is nested inside the same parent as another tag.
#
# Like head and body are siblings, since they’re both inside html
# and p tags are siblings, since they’re both inside body.

# %% [markdown]
# # A brief note on the Input data / website to be scrapped and used for implementing Web Scrapping technique :

# %% [markdown]
# The website / webpage used for Web Scrapping in this project is the National Weather Service’s website of the US.
#
# It contains up-to-date weather forecasts for every location in the US.
#
# If it is required to analyze this weather forecasts data, or download it
# for use in some other app, that is not possible as that weather data isn’t
# accessible as a CSV or via API, it can only be viewed on the NWS site.
#
# Hence, the need for implementing web scrapping through which we can  write some code that looks at the NWS site,
# grabs just the data we want to work with, and outputs it in the format we need.
#
# In this project we will scrape weather forecasts from the National Weather Service website of the US,
# and then analyze them using the Pandas library

# %% [markdown]
# # Implementation of Web Scrapping using requests and beautifulsoup libraries in python:

# %% [markdown]
# # A brief on the python 'requests library' :

# %% [markdown]
# In order to download Web pages for performing Web Scrapping, 'requests' Python library is used.
#
# The requests library  makes a 'GET' request to a web server,
# which will download the HTML contents of a given web page.
#
# There are several different types of requests that can be made using requests.

# %% [markdown]
# Importing 'requests' Python library to download the desired (Input) Web Page containing the weather forecast for implementing Web Scrapping using the requests.get() method:

# %%
from urllib.request import urlopen
import requests
page = requests.get("https://forecast.weather.gov/MapClick.php?lat=37.7772&lon=-122.4168")
#pg = requests.get("https://forecast.weather.gov/MapClick.php?lat=37.7772&lon=-122.4168#.YJzzREzhVPY")

# %% [markdown]
# After running requests.get(), a Response object is obtained.
#
# This object has a status_code property, which indicates if the page was downloaded successfully or not :

# %%
page
# Out:
# <Response [200]>

# %% [markdown]
# A status_code of 200 means that the page downloaded successfully, since a status code starting with a 2 generally indicates success,
# and a code starting with a 4 or a 5 indicates an error :

# %%
page.status_code
# Out:
# 200

# %% [markdown]
# To print out the HTML content of the page using the content property:

# %%
page.content
# Out:
# b'<!DOCTYPE html>\n<html class="no-js">\n    <head>\n        <!-- Meta -->\n        <meta name="viewport" content="width=device-width">\n        <link rel="schema.DC" href="http://purl.org/dc/elements/1.1/" /><title>National Weather Service</title><meta name="DC.title" content="National Weather Service" /><meta name="DC.description" content="NOAA National Weather Service National Weather Service" /><meta name="DC.creator" content="US Department of Commerce, NOAA, National Weather Service" /><meta name="DC.date.created" scheme="ISO8601" content="" /><meta name="DC.language" scheme="DCTERMS.RFC1766" content="EN-US" /><meta name="DC.keywords" content="weather, National Weather Service" /><meta name="DC.publisher" content="NOAA\'s National Weather Service" /><meta name="DC.contributor" content="National Weather Service" /><meta name="DC.rights" content="http://www.weather.gov/disclaimer.php" /><meta name="rating" content="General" /><meta name="robots" content="index,follow" />\n\n      
# ...

# %% [markdown]
# # A brief on the python 'BeautifulSoup library' :

# %% [markdown]
# Beautiful Soup is a Python library for extracting structured data from a website.
#
# It allows us to parse data from HTML and XML files.
#
# It acts as a helper module and interacts with HTML in a better way than how other available developer tools would interact with a web page.
#
# It works with parsers like lxml and html5lib to provide Python ways of navigating, searching, and modifying the parse tree.
#
# It converts the documents being fetched to Unicode and outgoing documents to UTF-8 unless the document intrinsic doesn't specify an encoding or Beautiful Soup is unable to detect one in the rarest of the cases.
#
# It is also considered to be faster as compared to other general parsing or scraping techniques.

# %% [markdown]
# # To Import and use the BeautifulSoup python library to parse the HTML document, corresponding to the Web page being scrapped, downloaded/obtained through using 'requests' and to extract the text from the div tag oh the HTML document:

# %%
from bs4 import BeautifulSoup

# %% [markdown]
# To create an instance of the BeautifulSoup class 'soup' to parse the HTML document :

# %%
soup_wf = BeautifulSoup(page.content, 'html.parser')

# %% [markdown]
# To print out the HTML content of the Web page used for implementing Web Scrapping , formatted nicely, using the 'prettify' method on the BeautifulSoup object 'soup' :

# %%
print(soup_wf.prettify())
# Out:
# <!DOCTYPE html>
# <html class="no-js">
#  <head>
#   <!-- Meta -->
#   <meta content="width=device-width" name="viewport"/>
#   <link href="http://purl.org/dc/elements/1.1/" rel="schema.DC"/>
#   <title>
#    National Weather Service
#   </title>
#   <meta content="National Weather Service" name="DC.title">
#    <meta content="NOAA National Weather Service National Weather Service" name="DC.description"/>
#    <meta content="US Department of Commerce, NOAA, National Weather Service" name="DC.creator"/>
#    <meta content="" name="DC.date.created" scheme="ISO8601"/>
#    <meta content="EN-US" name="DC.language" scheme="DCTERMS.RFC1766"/>
#    <meta content="weather, National Weather Service" name="DC.keywords"/>
#    <meta content="NOAA's National Weather Service" name="DC.publisher"/>
#    <meta content="National Weather Service" name="DC.contributor"/>
#    <meta content="http://www.weather.gov/disclaimer.php" name="DC.rights"/>
#    <meta content="General" name="rating"/>
# ...

# %% [markdown]
# Since, all  tags are nested, it is required to move through the structure one level at a time.
#
# At first need to select all the elements at the top level of the HTML document using the children property of soup.
#
# children returns a list generator, so we need to call the list function on it:

# %%
list(soup_wf.children)
# Out:
# ['html',
#  '\n',
#  <html class="no-js">
#  <head>
#  <!-- Meta -->
#  <meta content="width=device-width" name="viewport"/>
#  <link href="http://purl.org/dc/elements/1.1/" rel="schema.DC"/><title>National Weather Service</title><meta content="National Weather Service" name="DC.title"><meta content="NOAA National Weather Service National Weather Service" name="DC.description"/><meta content="US Department of Commerce, NOAA, National Weather Service" name="DC.creator"/><meta content="" name="DC.date.created" scheme="ISO8601"/><meta content="EN-US" name="DC.language" scheme="DCTERMS.RFC1766"/><meta content="weather, National Weather Service" name="DC.keywords"/><meta content="NOAA's National Weather Service" name="DC.publisher"/><meta content="National Weather Service" name="DC.contributor"/><meta content="http://www.weather.gov/disclaimer.php" name="DC.rights"/><meta content="General" name="rating"/><meta content="index,follow" name="robots"/>
#  <!-- Icons -->
# ...

# %%
'''It can be observed in the preceding code output that there are two tags at the top level of the HTML page in concern — the initial <!DOCTYPE html> tag, and the <html> tag'''
# Out:
# 'It can be observed in the preceding code output that there are two tags at the top level of the HTML page in concern — the initial <!DOCTYPE html> tag, and the <html> tag'

# %% [markdown]
# To check the type of each element in the list :

# %%
[type(item) for item in list(soup_wf.children)]
# Out:
# [bs4.element.Doctype,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString]

# %% [markdown]
# It can be observed in the preceding code output that all of the items are BeautifulSoup objects:
#
# The first is a Doctype object, which contains information about the type of the document.
#
# The second is a Navigable String, which represents text found in the HTML document.
#
# The third item is a Tag object, which contains other nested tags.
#
# The fourth is also a Navigable String, which represents text found in the HTML document.
#
# The most important object type,is the Tag object that allows to navigate through an HTML document, and extract other tags and text

# %% [markdown]
# To select the html tag and its children by taking the third item in the list:

# %%
html1 = list(soup_wf.children)[2]

# %% [markdown]
# Each item in the list returned by the children property is also a BeautifulSoup object, hence the children method could also be called on the html.
#
# To find the children inside the html tag:

# %%
list(html1.children)
# Out:
# ['\n',
#  <head>
#  <!-- Meta -->
#  <meta content="width=device-width" name="viewport"/>
#  <link href="http://purl.org/dc/elements/1.1/" rel="schema.DC"/><title>National Weather Service</title><meta content="National Weather Service" name="DC.title"><meta content="NOAA National Weather Service National Weather Service" name="DC.description"/><meta content="US Department of Commerce, NOAA, National Weather Service" name="DC.creator"/><meta content="" name="DC.date.created" scheme="ISO8601"/><meta content="EN-US" name="DC.language" scheme="DCTERMS.RFC1766"/><meta content="weather, National Weather Service" name="DC.keywords"/><meta content="NOAA's National Weather Service" name="DC.publisher"/><meta content="National Weather Service" name="DC.contributor"/><meta content="http://www.weather.gov/disclaimer.php" name="DC.rights"/><meta content="General" name="rating"/><meta content="index,follow" name="robots"/>
#  <!-- Icons -->
# ...

# %% [markdown]
# It can be observed in the preceding code output that there are quite a few tags here,like,  head, body etc.
#
# It is required to extract the text inside the div tag, hence need to move into the body of the concerned HTML document:

# %%
b1 = list(html1.children)[3]

# %% [markdown]
# To get the div tag by finding the children of the body tag:

# %%
list(b1.children)
# Out:
# ['\n',
#  <main class="container">
#  <header class="row clearfix" id="page-header">
#  <a class="pull-left" href="http://www.noaa.gov" id="header-noaa"><img alt="National Oceanic and Atmospheric Administration" src="/css/images/header_noaa.png"/></a>
#  <a class="pull-left" href="http://www.weather.gov" id="header-nws"><img alt="National Weather Service" src="/css/images/header_nws.png"/></a>
#  <a class="pull-right" href="http://www.commerce.gov" id="header-doc"><img alt="United States Department of Commerce" src="/css/images/header_doc.png"/></a>
#  </header>
#  <nav class="navbar navbar-default row" role="navigation">
#  <div class="container-fluid">
#  <div class="navbar-header">
#  <button class="navbar-toggle collapsed" data-target="#top-nav" data-toggle="collapse" type="button">
#  <span class="sr-only">Toggle navigation</span>
#  <span class="icon-bar"></span>
#  <span class="icon-bar"></span>
#  <span class="icon-bar"></span>
#  </button>
#  </div>
# ...

# %% [markdown]
# To isolate the div tag:

# %%
div1 = list(b1.children)[1]

# %% [markdown]
# After isolating the div tag, the 'get_text' method is used to extract all of the text inside the div tag:

# %%
div1.get_text()
# Out:
# "\n\n\n\n\n\n\n\n\n\nToggle navigation\n\n\n\n\n\n\n\nHOME\nFORECAST\xa0LocalGraphicalAviationMarineRivers and LakesHurricanesSevere WeatherFire WeatherSun/MoonLong Range ForecastsClimate PredictionSpace Weather \nPAST WEATHER\xa0Past WeatherHeating/Cooling DaysMonthly TemperaturesRecordsAstronomical Data \nSAFETY\xa0TsunamisFloodsBeach HazardsWildfireColdTornadoesAir QualityFogHeatHurricanesLightningSafe BoatingRip CurrentsThunderstormsSpace WeatherSun (Ultraviolet Radiation)Safety CampaignsWindDroughtWinter Weather \nINFORMATION\xa0Owlie's Kids PageWireless Emergency AlertsBrochuresWeather-Ready NationCooperative ObserversDaily BriefingDamage/Fatality/Injury StatisticsForecast ModelsGIS Data PortalNOAA Weather RadioPublicationsSKYWARN Storm SpottersStormReadyTsunamiReadyService Change Notices \nEDUCATION\xa0Be A Force of NatureNWS Education Home \nNEWS\xa0NWS NewsEventsSocial MediaPubs/Brochures/Booklets NWS Media Contacts \nSEARCH\xa0 \n\n\n\nSearch For\n\n\n\n\nNWS\n\nAll NOAA\n\
# ...

# %% [markdown]
# # To Find all instances of a tag at once ;

# %% [markdown]
# In order to extract a single tag, alternatively, the 'find_all' method, which will find all the instances of a tag on a page, is implemented for finding all the instances of the div tag:

# %%
soup_wf.find_all('div')
# Out:
# [<div class="container-fluid">
#  <div class="navbar-header">
#  <button class="navbar-toggle collapsed" data-target="#top-nav" data-toggle="collapse" type="button">
#  <span class="sr-only">Toggle navigation</span>
#  <span class="icon-bar"></span>
#  <span class="icon-bar"></span>
#  <span class="icon-bar"></span>
#  </button>
#  </div>
#  <div class="collapse navbar-collapse" id="top-nav">
#  <ul class="nav navbar-nav">
#  <li><a href="http://www.weather.gov">HOME</a></li>
# ...

# %% [markdown]
# Since 'find_all' returns a list, so it is required to loop through, or use list indexing, in order to to extract the text:

# %%
soup_wf.find_all('div')[0].get_text()
# Out:
# "\n\n\nToggle navigation\n\n\n\n\n\n\n\nHOME\nFORECAST\xa0LocalGraphicalAviationMarineRivers and LakesHurricanesSevere WeatherFire WeatherSun/MoonLong Range ForecastsClimate PredictionSpace Weather \nPAST WEATHER\xa0Past WeatherHeating/Cooling DaysMonthly TemperaturesRecordsAstronomical Data \nSAFETY\xa0TsunamisFloodsBeach HazardsWildfireColdTornadoesAir QualityFogHeatHurricanesLightningSafe BoatingRip CurrentsThunderstormsSpace WeatherSun (Ultraviolet Radiation)Safety CampaignsWindDroughtWinter Weather \nINFORMATION\xa0Owlie's Kids PageWireless Emergency AlertsBrochuresWeather-Ready NationCooperative ObserversDaily BriefingDamage/Fatality/Injury StatisticsForecast ModelsGIS Data PortalNOAA Weather RadioPublicationsSKYWARN Storm SpottersStormReadyTsunamiReadyService Change Notices \nEDUCATION\xa0Be A Force of NatureNWS Education Home \nNEWS\xa0NWS NewsEventsSocial MediaPubs/Brochures/Booklets NWS Media Contacts \nSEARCH\xa0 \n\n\n\nSearch For\n\n\n\n\nNWS\n\nAll NOAA\n\n\n\n\n \nABOU
# ...

# %%
for i in range(10, 21) :
    print(soup_wf.find_all('div')[i].get_text())
# Out:
# Multiple locations were found. Please select one of the following:
#
#
# Your local forecast office is
#
#
#
#
#
#
# Isolated Severe Thunderstorms and Flooding Potential in the Central U.S.
#
#             Isolated strong to severe thunderstorms are possible across parts of the southern and central Plains through Saturday. Large hail and severe wind gusts are the main threats. Heavy rainfall is forecast from the western Gulf Coast into the Midwest from this weekend into early next week. New and renewed river rises are possible across portions of eastern Texas.
#             Read More >
#
#
#
#
#
#
#
# Isolated Severe Thunderstorms and Flooding Potential in the Central U.S.
#
# ...

# %% [markdown]
# Again, in order to find only the first instance of a tag, the find method, which will return a single BeautifulSoup object is used:

# %%
soup_wf.find('div')
# Out:
# <div class="container-fluid">
# <div class="navbar-header">
# <button class="navbar-toggle collapsed" data-target="#top-nav" data-toggle="collapse" type="button">
# <span class="sr-only">Toggle navigation</span>
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# </button>
# </div>
# <div class="collapse navbar-collapse" id="top-nav">
# <ul class="nav navbar-nav">
# <li><a href="http://www.weather.gov">HOME</a></li>
# ...

# %% [markdown]
# # To Search for tags in the concerned HTML document by class and id :

# %% [markdown]
# To use Class and id to specify the elements we want to scrape :
#
# To use the find_all method to search for items by class or by id.

# %% [markdown]
#  To search for elements by class in the concerned HTML document:

# %% [markdown]
# To search for any div tag that has the class 'contentArea' :

# %%
soup_wf.find_all('div', class_='contentArea')
# Out:
# [<div class="contentArea">
#  <!-- Start Forecastsearch -->
#  <div class="" id="fcst-search">
#  <form action="https://forecast.weather.gov/zipcity.php" class="form-inline" id="getForecast" method="get" name="getForecast" role="form">
#  <div id="getfcst-body">
#  <input class="form-control" id="inputstring" name="inputstring" placeholder="" type="text"/>
#  <input class="btn btn-default" id="btnSearch" name="btnSearch" type="submit" value="Go"/>
#  <div id="txtHelp"><a href="javascript:void(window.open('http://weather.gov/ForecastSearchHelp.html','locsearchhelp','status=0,toolbar=0,location=0,menubar=0,directories=0,resizable=1,scrollbars=1,height=500,width=530').focus());">View Location Examples</a></div>
#  </div>
#  <div id="txtError">
#  <div id="errorNoResults" style="display:none;">Sorry, the location you searched for was not found. Please try another search.</div>
# ...

# %% [markdown]
# To look for any tag that has the class 'tombstone-container' :

# %%
soup_wf.find_all(class_='tombstone-container')
# Out:
# [<div class="tombstone-container">
#  <p class="period-name">Tonight<br/><br/></p>
#  <p><img alt="Tonight: Increasing clouds, with a low around 51. Southwest wind 9 to 13 mph. " class="forecast-icon" src="newimages/medium/nbkn.png" title="Tonight: Increasing clouds, with a low around 51. Southwest wind 9 to 13 mph. "/></p><p class="short-desc">Increasing<br/>Clouds</p><p class="temp temp-low">Low: 51 °F</p></div>,
#  <div class="tombstone-container">
#  <p class="period-name">Friday<br/><br/></p>
#  <p><img alt="Friday: Cloudy through mid morning, then gradual clearing, with a high near 63. Southwest wind 9 to 16 mph, with gusts as high as 22 mph. " class="forecast-icon" src="newimages/medium/bkn.png" title="Friday: Cloudy through mid morning, then gradual clearing, with a high near 63. Southwest wind 9 to 16 mph, with gusts as high as 22 mph. "/></p><p class="short-desc">Gradual<br/>Clearing</p><p class="temp temp-high">High: 63 °F</p></div>,
#  <div class="tombstone-container">
# ...

# %% [markdown]
#  To search for elements by id in the concerned HTML document:

# %% [markdown]
#  To search for elements / tags that contains the id 'fcst-search' in the concerned HTML document:

# %%
soup_wf.find_all(id="fcst-search")
# Out:
# [<div class="" id="fcst-search">
#  <form action="https://forecast.weather.gov/zipcity.php" class="form-inline" id="getForecast" method="get" name="getForecast" role="form">
#  <div id="getfcst-body">
#  <input class="form-control" id="inputstring" name="inputstring" placeholder="" type="text"/>
#  <input class="btn btn-default" id="btnSearch" name="btnSearch" type="submit" value="Go"/>
#  <div id="txtHelp"><a href="javascript:void(window.open('http://weather.gov/ForecastSearchHelp.html','locsearchhelp','status=0,toolbar=0,location=0,menubar=0,directories=0,resizable=1,scrollbars=1,height=500,width=530').focus());">View Location Examples</a></div>
#  </div>
#  <div id="txtError">
#  <div id="errorNoResults" style="display:none;">Sorry, the location you searched for was not found. Please try another search.</div>
#  <div id="errorMultipleResults" style="display:none">Multiple locations were found. Please select one of the following:</div>
# ...

# %% [markdown]
# To search for elements / tags that contains the id 'seven-day-forecast' in the concerned HTML document:

# %%
soup_wf.find_all(id='seven-day-forecast')
# Out:
# [<div class="panel panel-default" id="seven-day-forecast">
#  <div class="panel-heading">
#  <b>Extended Forecast for</b>
#  <h2 class="panel-title">
#  	    	    San Francisco CA	</h2>
#  </div>
#  <div class="panel-body" id="seven-day-forecast-body">
#  <div id="seven-day-forecast-container"><ul class="list-unstyled" id="seven-day-forecast-list"><li class="forecast-tombstone">
#  <div class="tombstone-container">
#  <p class="period-name">Tonight<br/><br/></p>
#  <p><img alt="Tonight: Increasing clouds, with a low around 51. Southwest wind 9 to 13 mph. " class="forecast-icon" src="newimages/medium/nbkn.png" title="Tonight: Increasing clouds, with a low around 51. Southwest wind 9 to 13 mph. "/></p><p class="short-desc">Increasing<br/>Clouds</p><p class="temp temp-low">Low: 51 °F</p></div></li><li class="forecast-tombstone">
#  <div class="tombstone-container">
#  <p class="period-name">Friday<br/><br/></p>
# ...

# %% [markdown]
# To search for elements / tags in the concerned HTML document using CSS selectors :
# Selectors are with which the CSS language helps to specify HTML tags to style
#
#     p a — finds all a tags inside of a p tag.
#
#     body p a — finds all a tags inside of a p tag inside of a body tag.
#
#     html body — finds all body tags inside of an html tag.
#
#     p.outer-text — finds all p tags with a class of outer-text.
#
#     p first — finds all p tags with an id of first.
#
#     body p.outer-text — finds any p tags with a class of outer-text inside of a body tag.

# %% [markdown]
# # To search for elements / tags in the concerned HTML document using CSS selectors :

# %% [markdown]
# BeautifulSoup objects support searching a page via CSS selectors using the select method.
#
# The select method also returns a list of BeautifulSoup objects.
#
# To use CSS selectors to find all the p tags in our concerned HTML document that are inside of a div like this :

# %%
soup_wf.select("div p")
# Out:
# [<p>
#  <input checked="checked" id="nws" name="affiliate" type="radio" value="nws.noaa.gov"/>
#  <label class="search-scope" for="nws">NWS</label>
#  <input id="noaa" name="affiliate" type="radio" value="noaa.gov"/>
#  <label class="search-scope" for="noaa">All NOAA</label>
#  </p>,
#  <p>Your local forecast office is</p>,
#  <p>
#              Isolated strong to severe thunderstorms are possible across parts of the southern and central Plains through Saturday. Large hail and severe wind gusts are the main threats. Heavy rainfall is forecast from the western Gulf Coast into the Midwest from this weekend into early next week. New and renewed river rises are possible across portions of eastern Texas.
#              <a href="http://www.wpc.ncep.noaa.gov/discussions/hpcdiscussions.php?disc=pmdspd" target="_blank">Read More &gt;</a>
#  </p>,
#  <p class="myforecast-current">NA</p>,
#  <p class="myforecast-current-lrg">50°F</p>,
#  <p class="myforecast-current-sm">10°C</p>,
# ...

# %% [markdown]
# To Find the div with id seven-day-forecast, and assign it to sd variable :

# %%
sd = soup_wf.find(id="seven-day-forecast")
sd
# Out:
# <div class="panel panel-default" id="seven-day-forecast">
# <div class="panel-heading">
# <b>Extended Forecast for</b>
# <h2 class="panel-title">
# 	    	    San Francisco CA	</h2>
# </div>
# <div class="panel-body" id="seven-day-forecast-body">
# <div id="seven-day-forecast-container"><ul class="list-unstyled" id="seven-day-forecast-list"><li class="forecast-tombstone">
# <div class="tombstone-container">
# <p class="period-name">Tonight<br/><br/></p>
# <p><img alt="Tonight: Increasing clouds, with a low around 51. Southwest wind 9 to 13 mph. " class="forecast-icon" src="newimages/medium/nbkn.png" title="Tonight: Increasing clouds, with a low around 51. Southwest wind 9 to 13 mph. "/></p><p class="short-desc">Increasing<br/>Clouds</p><p class="temp temp-low">Low: 51 °F</p></div></li><li class="forecast-tombstone">
# <div class="tombstone-container">
# <p class="period-name">Friday<br/><br/></p>
# ...

# %% [markdown]
# To find each individual weather forecast item Inside sd containing class tombstone-container:

# %%
fi = sd.find_all(class_="tombstone-container")
fi
# Out:
# [<div class="tombstone-container">
#  <p class="period-name">Tonight<br/><br/></p>
#  <p><img alt="Tonight: Increasing clouds, with a low around 51. Southwest wind 9 to 13 mph. " class="forecast-icon" src="newimages/medium/nbkn.png" title="Tonight: Increasing clouds, with a low around 51. Southwest wind 9 to 13 mph. "/></p><p class="short-desc">Increasing<br/>Clouds</p><p class="temp temp-low">Low: 51 °F</p></div>,
#  <div class="tombstone-container">
#  <p class="period-name">Friday<br/><br/></p>
#  <p><img alt="Friday: Cloudy through mid morning, then gradual clearing, with a high near 63. Southwest wind 9 to 16 mph, with gusts as high as 22 mph. " class="forecast-icon" src="newimages/medium/bkn.png" title="Friday: Cloudy through mid morning, then gradual clearing, with a high near 63. Southwest wind 9 to 16 mph, with gusts as high as 22 mph. "/></p><p class="short-desc">Gradual<br/>Clearing</p><p class="temp temp-high">High: 63 °F</p></div>,
#  <div class="tombstone-container">
# ...

# %% [markdown]
# # To Extract and print the fourth weather forecast item :

# %%
t = fi[3]
print(t.prettify())
# Out:
# <div class="tombstone-container">
#  <p class="period-name">
#   Saturday
#   <br/>
#   <br/>
#  </p>
#  <p>
#   <img alt="Saturday: Partly sunny, with a high near 64. Southwest wind 8 to 13 mph. " class="forecast-icon" src="newimages/medium/bkn.png" title="Saturday: Partly sunny, with a high near 64. Southwest wind 8 to 13 mph. "/>
#  </p>
#  <p class="short-desc">
#   Partly Sunny
#  </p>
#  <p class="temp temp-high">
#   High: 64 °F
#  </p>
# </div>

# %% [markdown]
# # It is observed from the output of the preceding code that inside the weather forecast item fi is all the information required to be extracted from the Weather Forecasting Webpage.
#
# There are four basic pieces of information that can be extracted from this concerned Weather Forecasting Webpage's content:
#
#     The time period / name of the weather forecast item — in this case : Friday.
#
#     The description of the realted weather conditions of the weather forecast item — this is stored in the title property of img, in this case : Friday: Cloudy through mid morning, then gradual clearing, with a high near 64. Southwest wind 8 to 14 mph, with gusts as high as 18 mph.
#
#     A short description of the weather conditions related to the of the weather forecast item — in this case, GradualClearing.
#
#     The temperature related to the weather forecast item — in this case, High: 64 °F.

# %% [markdown]
# # To extract the name of the weather forecast item, the short description related to it, and the corresponding temperature of the particular weather forecast item:

# %% [markdown]
# To extract the time period / name of the weather forecast item:

# %%
time1 = t.find(class_="period-name").get_text()
time1
# Out:
# 'Saturday'

# %% [markdown]
# To extract the description of the realted weather conditions of the weather forecast item:

# %%
short_desc1 = t.find(class_="short-desc").get_text()
short_desc1
# Out:
# 'Partly Sunny'

# %% [markdown]
# To extract the The temperature of the weather forecast item:

# %%
temp1 = t.find(class_="temp").get_text()
temp1
# Out:
# 'High: 64 °F'

# %% [markdown]
# # To extract the 'title' attribute from the img tag of the concerned weather forecast item from the HTML document of the corresponding Weather Forecasting webpage required to be Scrapped.
#
# In order to do this it is required to  treat the BeautifulSoup object like a dictionary,
# and pass in the attribute we want as a key:

# %%
img1 = t.find("img")
title1 = img1['title']
print(title1)
# Out:
# Saturday: Partly sunny, with a high near 64. Southwest wind 8 to 13 mph.

# %% [markdown]
# # To Extract all the information from the Weather Forecasting webpage
#
# Previously it has been demonstrated the way to extract each individual piece of information, from the concerned weather forecasting webpage of a single weather forecasting item,
#
# Now combining all knowledge gained through it with CSS selectors and list comprehensions to extract everything at once

# %% [markdown]
# # To Select all items with the class period-name inside an item with the class tombstone-container in sd :

# %%
p_tags1 = sd.select(".tombstone-container .period-name")
p_tags1
# Out:
# [<p class="period-name">Tonight<br/><br/></p>,
#  <p class="period-name">Friday<br/><br/></p>,
#  <p class="period-name">Friday<br/>Night</p>,
#  <p class="period-name">Saturday<br/><br/></p>,
#  <p class="period-name">Saturday<br/>Night</p>,
#  <p class="period-name">Sunday<br/><br/></p>,
#  <p class="period-name">Sunday<br/>Night</p>,
#  <p class="period-name">Monday<br/><br/></p>,
#  <p class="period-name">Monday<br/>Night</p>]

# %% [markdown]
# # To use a list comprehension to call the get_text method on each of the BeautifulSoup object in sd :
#
# inorder to obtain each of the period names of each of the weather forecast items :

# %%
tm_pr = [k.get_text() for k in p_tags1]
tm_pr
# Out:
# ['Tonight',
#  'Friday',
#  'FridayNight',
#  'Saturday',
#  'SaturdayNight',
#  'Sunday',
#  'SundayNight',
#  'Monday',
#  'MondayNight']

# %% [markdown]
# # To Select all items with the class short-desc inside an item with the class tombstone-container in sd and to use a list comprehension to call the get_text method on each of the BeautifulSoup object in sd
#
# inorder to obtain each of the short descriptions of each of the weather forecast items :

# %%
short_desc1 = [d.get_text() for d in sd.select(".tombstone-container .short-desc")]
short_desc1
# Out:
# ['IncreasingClouds',
#  'GradualClearing',
#  'Mostly Cloudy',
#  'Partly Sunny',
#  'Partly Cloudy',
#  'Mostly Sunny',
#  'Mostly Cloudy',
#  'Partly Sunny',
#  'Partly Cloudy']

# %% [markdown]
# # To Select all items with the class temp inside an item with the class tombstone-container in sd and to use a list comprehension to call the get_text method on each of the BeautifulSoup object in sd
#
# inorder to obtain each of the temparatures of each of the weather forecast items :

# %%
temp1 = [t1.get_text() for t1 in sd.select(".tombstone-container .temp")]
temp1
# Out:
# ['Low: 51 °F',
#  'High: 63 °F',
#  'Low: 51 °F',
#  'High: 64 °F',
#  'Low: 52 °F',
#  'High: 65 °F',
#  'Low: 52 °F',
#  'High: 63 °F',
#  'Low: 51 °F']

# %% [markdown]
# # To Select all items stored in the title property of the img tag with the class forecast-icon inside img item with the class tombstone-container in sd and to use a list comprehension to call the get_text method on each of the BeautifulSoup object in sd
#
# inorder to obtain each of the description of the Weather conditions of each of the weather forecast items :

# %%
wc1 = [w["title"] for w in sd.select(".tombstone-container img")]
wc1
# Out:
# ['Tonight: Increasing clouds, with a low around 51. Southwest wind 9 to 13 mph. ',
#  'Friday: Cloudy through mid morning, then gradual clearing, with a high near 63. Southwest wind 9 to 16 mph, with gusts as high as 22 mph. ',
#  'Friday Night: Mostly cloudy, with a low around 51. West wind 11 to 18 mph, with gusts as high as 25 mph. ',
#  'Saturday: Partly sunny, with a high near 64. Southwest wind 8 to 13 mph. ',
#  'Saturday Night: Partly cloudy, with a low around 52. Southwest wind 6 to 15 mph, with gusts as high as 20 mph. ',
#  'Sunday: Mostly sunny, with a high near 65.',
#  'Sunday Night: Mostly cloudy, with a low around 52.',
#  'Monday: Partly sunny, with a high near 63.',
#  'Monday Night: Partly cloudy, with a low around 51.']

# %% [markdown]
# # To combine our Web Scraped data otained by Scrapping the National Weather Service’s website of the US containing Weather forecast data into a Pandas Dataframe

# %% [markdown]
# To combine all the Web Scrapped data, scrapped from the Weather Forecasting website into a Pandas DataFrame inorder to Analyze this Web Scrapped data .
#
# A DataFrame is an object that can store tabular data, making data analysis easy.
#
# To call the DataFrame class, and pass in each list of the Weather Forecast
# items,  that has been obtained through Web Scrapping of the
# Weather Forecast Website, as part of a dictionary.
#
# Each dictionary key will become a column in the DataFrame,
# and each list passed in the dataframe will become the values in the
# column of the dataframe:

# %%
#Importing pandas library
import pandas as pd

wforecast = pd.DataFrame({
    "Time_period": tm_pr,
    "Short_desc": short_desc1,
    "Temperature": temp1,
    "Description_wc":wc1
})

# %%
wforecast
# Out:
#      Time_period        Short_desc  Temperature  \
# 0        Tonight  IncreasingClouds   Low: 51 °F
# 1         Friday   GradualClearing  High: 63 °F
# 2    FridayNight     Mostly Cloudy   Low: 51 °F
# 3       Saturday      Partly Sunny  High: 64 °F
# 4  SaturdayNight     Partly Cloudy   Low: 52 °F
# 5         Sunday      Mostly Sunny  High: 65 °F
# 6    SundayNight     Mostly Cloudy   Low: 52 °F
# 7         Monday      Partly Sunny  High: 63 °F
# 8    MondayNight     Partly Cloudy   Low: 51 °F
#
#                                       Description_wc
# 0  Tonight: Increasing clouds, with a low around ...
# 1  Friday: Cloudy through mid morning, then gradu...
# 2  Friday Night: Mostly cloudy, with a low around...
# 3  Saturday: Partly sunny, with a high near 64. S...
# 4  Saturday Night: Partly cloudy, with a low arou...
# 5         Sunday: Mostly sunny, with a high near 65.
# 6  Sunday Night: Mostly cloudy, with a low around...
# 7         Monday: Partly sunny, with a high near 63.
# ...

# %% [markdown]
# # To perform some Data Analysis on the Web Scrapped data obtained from scrapping the Weather Forecast website and then converted into a dataframe using pandas library in python:

# %%
#shape of the dataframe indicates 9 rows and 5 Columns inthe dataset
wforecast.shape
# Out:
# (9, 4)

# %%
wforecast.head(3)
# Out:
#    Time_period        Short_desc  Temperature  \
# 0      Tonight  IncreasingClouds   Low: 51 °F
# 1       Friday   GradualClearing  High: 63 °F
# 2  FridayNight     Mostly Cloudy   Low: 51 °F
#
#                                       Description_wc
# 0  Tonight: Increasing clouds, with a low around ...
# 1  Friday: Cloudy through mid morning, then gradu...
# 2  Friday Night: Mostly cloudy, with a low around...

# %% [markdown]
# Pre-processing the data in the Datframe :

# %%
import numpy as np
wforecast = wforecast.replace('?',np.nan)

# %%
#To Replace the zero values in the DataFrame to NaN
wforecast.replace(str(0), np.nan, inplace=True)
wforecast.replace(0, np.nan, inplace=True)

# %%
#Counting the Number of NaNs in the DataFrame
count_nan = len(wforecast) - wforecast.count()
count_nan
# Out:
# Time_period       0
# Short_desc        0
# Temperature       0
# Description_wc    0
# dtype: int64

# %%
# To find all the unique values of Time_period 
wforecast['Time_period'].unique()
# Out:
# array(['Tonight', 'Friday', 'FridayNight', 'Saturday', 'SaturdayNight',
#        'Sunday', 'SundayNight', 'Monday', 'MondayNight'], dtype=object)

# %%
# To find total the counts of occurrence of each of the unique possble values of Short_desc
wforecast['Short_desc'].value_counts()
# Out:
# Mostly Cloudy       2
# Partly Sunny        2
# Partly Cloudy       2
# Mostly Sunny        1
# IncreasingClouds    1
# GradualClearing     1
# Name: Short_desc, dtype: int64

# %%
wforecast["Temperature"]
# Out:
# 0     Low: 51 °F
# 1    High: 63 °F
# 2     Low: 51 °F
# 3    High: 64 °F
# 4     Low: 52 °F
# 5    High: 65 °F
# 6     Low: 52 °F
# 7    High: 63 °F
# 8     Low: 51 °F
# Name: Temperature, dtype: object

# %% [markdown]
# To use lambda function to  pull out the numeric temperature values from the Weather Forecast data in the dataframe:

# %%
wforecast['Temperature'] = wforecast['Temperature'].apply(lambda x: x.split()[1])

# %%
wforecast['Temp_nmr']= pd.to_numeric(wforecast['Temperature'])

# %%
wforecast['Temp_nmr']
# Out:
# 0    51
# 1    63
# 2    51
# 3    64
# 4    52
# 5    65
# 6    52
# 7    63
# 8    51
# Name: Temp_nmr, dtype: int64

# %% [markdown]
# To find the mean of all the high and low temperatures:

# %%
wforecast["Temp_nmr"].mean()
# Out:
# 56.888888888888886

# %%
#To verify the data types of the DataFrame
wforecast.dtypes
# Out:
# Time_period       object
# Short_desc        object
# Temperature       object
# Description_wc    object
# Temp_nmr           int64
# dtype: object

# %% [markdown]
# To only select the rows that happen at night:

# %%
is_nyt = wforecast["Temperature"].str.contains("Low")
is_nyt
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# Name: Temperature, dtype: bool

# %%
#f = lambda x : 1 if x==True else 0
wforecast["is_nyt"] = (wforecast["is_nyt"] == True).astype(int)
wforecast["is_nyt"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'is_nyt'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-183-ed80830f8795> in <module>
# ...

# %%
wforecast["is_nyt"]=is_nyt
wforecast

# %%
#wforecast.drop(['temp_nmrc'], axis =1)

# %% [markdown]
# To find out which all Time_period had the high Temparatures :

# %%
tempr1 = wforecast.sort_values(["Temperature"], axis=0, ascending=False)[:15]
tempr1

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import re
import time
from datetime import datetime
import matplotlib.dates as mdates
import matplotlib.ticker as ticker

# %%
#Loading BokehJS
from bokeh.models import ColumnDataSource
from bokeh.transform import dodge
import math
from bokeh.io import curdoc
curdoc().clear()
from bokeh.io import push_notebook, show, output_notebook
from bokeh.layouts import row
from bokeh.plotting import figure
from bokeh.transform import factor_cmap
from bokeh.models import Legend
output_notebook()

# %% [markdown]
# Plot to visualize the Time periods with the Highest Temperatures :

# %%
p1 = figure(x_range=wforecast.iloc[:,0], plot_width=800, plot_height=550, title="Time_period with the Highest Temperatures", toolbar_location=None, tools="")

p1.vbar(x=wforecast.iloc[:,0], top=wforecast.iloc[:,2], width=0.9)

p1.xgrid.grid_line_color = None
p1.y_range.start = 0
p1.xaxis.major_label_orientation = math.pi/2

show(p1)

# %% [markdown]
# Plot to visualize the Time periods with the Highest Temperatures where Temperature greater than 55 F:

# %%
data1 = wforecast[wforecast['Temp_nmr'] > 55]

# %%
data1 = data1.sort_values(['Time_period'],axis=0, ascending=False)[:15]
data1

# %%
p = figure(x_range=data1.iloc[:,0], plot_width=800, plot_height=600, title="Time periods with the Highest Temperatures where Temperature greater than 55 F", toolbar_location=None, tools="")

p.vbar(x=data1.iloc[:,0], top=data1.iloc[:,2], width=0.9)

p.xgrid.grid_line_color = None
p.y_range.start = 0
p.xaxis.major_label_orientation = math.pi/2

show(p)
